# %%
career_data = {
    "ai": "Artificial Intelligence is the simulation of human intelligence in machines.",
    "ml": "Machine Learning allows computers to learn from data.",
    "dl": "Deep Learning is a subset of Machine Learning.",
    "cnn": "CNN is mainly used for image classification tasks.",
    "python": "Python is a popular programming language for AI and Data Science.",
    "github": "GitHub is used to store and manage code repositories.",
    "portfolio": "A portfolio showcases your projects and skills.",
    "internship": "Internships help students gain practical industry experience."
}

while True:
    user = input("Ask a question: ").lower()

    if user == "exit":
        print("Goodbye!")
        break

    elif user in career_data:
        print(career_data[user])

    else:
        print("Sorry, I don't know the answer.")
# Out:
# Ask a question: python
# Python is a popular programming language for AI and Data Science.
